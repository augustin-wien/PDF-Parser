# %%
# Import necessary libraries
import base64
import json
import sys 
import os
import fitz
import requests
import re
from fitz import Document, Page, Rect

# %% [markdown]
# ## Load page 2 and crop to left page (page 4)

# %%
src = fitz.open("../PyMuPDF_playground/574_augustin_fertig_kontrolle.pdf")
new_doc = fitz.open()  # empty output PDF

page = src.load_page(2)
r = page.rect
d = fitz.Rect(
    # CropBox displacement if being set
    page.cropbox_position,
    page.cropbox_position,
)  # starting at (0, 0)

r1 = r
r1.x1 = r1.x1 / 2  # left side of double page
r2 = r1 + (r1.width, 0, r1.width, 0)  # right side of double page
# r2 = r + (r.width / 2, 0, 0, 0)  # right side of double page

r2 += d  # add the CropBox displacement
new_page_left = new_doc.new_page(-1, width=r1.width, height=r1.height)
new_page_left.show_pdf_page(
    new_page_left.rect,
    src,
    page.number,
    clip=r1,
)
# Out:
# 80

# %% [markdown]
# ### 1. Option to use get_text()

# %%
text_bytes_left = new_page_left.get_text().encode("utf8") # get plain text (is in UTF-8)
text_left = text_bytes_left.decode('utf-8')
print(text_left)
# Out:
# 574
# 4
# einsicht
# WIENER WINKEL
# wos is los …
# … beim Augustin
# Pseudo-Christo, 1010 Wien
# Foto: Nina Strasser
# D
# as deutschsprachige Straßenzeitungstreffen ende
# april in Hamburg stand im Zeichen des Zusam-
# menhalts. 21 Straßenzeitungen aus Österreich,
# Deutschland und der Schweiz sind der einladung der
# Kolleg:innen von Hinz&Kunzt gefolgt, haben sich ausge-
# tauscht und vor allem gegenseitig bestärkt. Denn  Stärke
# brauchen wir jetzt, um unsere arbeit weiterzuführen.
# Die Teuerungen bringen mehr armut – wir sind mehr
# gefordert. Um diese zusätzliche Unterstützungsarbeit
# für  Betroffene leisten zu können, ohne
# uns dabei selbst auszubeuten, haben
# wir uns bei der Konferenz ausgiebig
# dem Thema «Fundraising» gewidmet.
# nicht nur die entwicklung der Print-
# medien, auch Corona hat uns allen
# einbußen bei den  verkaufszahlen
#  beschert. Wir wollen aber weiterhin
#  Unterstützung in sozialrechtlichen Fra-
# gen, Begleitung bei medizinischen notfällen, Zur-verfü-
# gung-Stellen von Speis & Trank, Rechtsberatung und Teil-
# nahme an Kulturprojekten anbieten.
# Wie können wir all das über den Zeitungsverkauf
# hinaus finanzieren? erste ansätze gibt es bereits: in
# Deutschland und der Schweiz vertrauen Straßenzeitun-
# gen auf ihren «Freundeskreis», bei uns in Wien sind wir
# ganz vernarrt in unsere liebhaber:innen. Diese  modelle
#  beinhalten nicht nur finanzielle Unterstützung, sondern
# auch ein Zusammenkommen von Spender:innen und
# verkäufer:innen, bereichernder austausch inklusive. Das
# Fazit des Straßenzeitungs-netzwerks: Diese Unterstüt-
# zung wollen wir pflegen und ausbauen. Denn gemein-
# sam mit euch schaffen wir solidarischen mehrwert!
# cp
# Beginn: ab sofort
# Umfang: 15 Stunden zu Beginn
# (spätere Stundenanzahl auf
# verhandlungsbasis)
# Geld: 998 euro brutto/monat
# Wir suchen eine:n Fundraiser:in mit:
# •�
# erfahrung und Freude bei ak-
# quise und im  Umgang mit gro-
# ßen und kleinen Spender:innen
# •�
# eDv- und Datenbankkenntnissen
# •�
# lust auf das erstellen von Kon-
# zepten & Texten zur  erweiterung
# unserer Spender:innen-liste
# •�
# interesse an einer sinnstiften-
# den Tätigkeit mit hoher eigen-
# verantwortung und flexibler
# arbeitszeit einteilung
# Was erwartet dich bei uns?
# Wir sind ein zwölfköpfiges Team, das
# alle zwei Wochen den Augustin heraus-
# gibt, augustin-verkäufer:innen unter-
# stützt und darüber hinaus viele  Projekte
# betreut. Wir arbeiten ohne Chef:in.
#  Unsere Gehälter sind alle gleich.
# Dein Aufgabengebiet umfasst
# folgende Bereiche:
# •�
# Betreuung bestehender
# Spender:innen
# •�
# Strategieplanung und -umset-
# zung zur Gewinnung neuer
# Spender:innen
# •�
# Zusammenarbeit mit dem
#  Gesamtteam und der Öffentlich-
# keitsarbeit im Besonderen
# Bei Interesse schick uns bitte bis 30.
# Mai ein paar Infos über dich selbst:
# •�
# in welchen Kontexten arbeitest
# du?
# •�
# aus welchen Projekten, vereinen,
# nGos trägst du deine erfahrun-
# gen zusammen?
# Post an uns:
# verein@augustin.or.at
# oder verein Sand & Zeit,
# Reinprechtsdorfer Str. 31, 1050 Wien
# Wir freuen uns auf deine Post!
# Das Augustin-Team
# gesucht!
# Fundraiser:in
# für den
# Gemeinsam
# schaffen wir
# solidarischen
# Mehrwert!

# %% [markdown]
# ### 2. Option to print out each line with meta information

# %%
def flags_decomposer(flags):
    """Make font flags human readable."""
    l = []
    if flags & 2 ** 0:
        l.append("superscript")
    if flags & 2 ** 1:
        l.append("italic")
    if flags & 2 ** 2:
        l.append("serifed")
    else:
        l.append("sans")
    if flags & 2 ** 3:
        l.append("monospaced")
    else:
        l.append("proportional")
    if flags & 2 ** 4:
        l.append("bold")
    return ", ".join(l)


# read page text as a dictionary, suppressing extra spaces in CJK fonts
blocks = new_page_left.get_text("dict", flags=11)["blocks"]
for b in blocks:  # iterate through the text blocks
    for l in b["lines"]:  # iterate through the text lines
        for s in l["spans"]:  # iterate through the text spans
            print("")
            font_properties = "Font: '%s' (%s), size %g, color #%06x" % (
                s["font"],  # font name
                flags_decomposer(s["flags"]),  # readable font flags
                s["size"],  # font size
                s["color"],  # font color
            )
            print("Text: '%s'" % s["text"])  # simple print of text
            print(font_properties)
# Out:
# Text: '574'
# Font: 'MyriadPro-BlackCond' (serifed, proportional, bold), size 13.9298, color #f3664e
#
# Text: '4'
# Font: 'MyriadPro-Bold' (serifed, proportional, bold), size 24, color #000000
#
# Text: 'einsicht'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 14.3543, color #f3664e
#
# Text: 'WIENER WINKEL'
# Font: 'MyriadPro-SemiCn' (serifed, proportional), size 24.2388, color #000000
#
# Text: 'wos is los …'
# Font: 'MyriadPro-Semibold' (serifed, proportional, bold), size 14.9238, color #000000
#
# Text: '… beim Augustin'
# Font: 'MyriadPro-Semibold' (serifed, proportional, bold), size 14.9238, color #000000
#
# Text: 'Pseudo-Christo, 1010 Wien '
# Font: 'MyriadPro-BoldSemiCn' (serifed, proportional, bold), size 7.95019, color #000000
#
# Text: 'Foto: Nina Strasser'
# Font: 'MyriadPro-BoldSemiCn' (serifed, proportional, bold), size 7.95019, color #000000
#
# Text: 'D'
# Font: 'Sentinel-Book' (serifed, proportional), size 37.8081, color #f3664e
#
# Text: 'as deutschsprachige Straßenzeitungstreffen ende '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.71655, color #000000
#
# Text: 'april in Hamburg stand im Zeichen des Zusam-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.76408, color #000000
#
# Text: 'menhalts. 21 Straßenzeitungen aus Österreich, '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.81753, color #000000
#
# Text: 'Deutschland und der Schweiz sind der einladung der '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.7945, color #000000
#
# Text: 'Kolleg:innen von '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #000000
#
# Text: 'Hinz&Kunzt'
# Font: 'MyriadPro-It' (italic, serifed, proportional), size 8.75589, color #000000
#
# Text: ' gefolgt, haben sich ausge-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #000000
#
# Text: 'tauscht und vor allem gegenseitig bestärkt. Denn  Stärke '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.74865, color #000000
#
# Text: 'brauchen wir jetzt, um unsere arbeit weiterzuführen. '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.8061, color #000000
#
# Text: 'Die Teuerungen bringen mehr armut – wir sind mehr '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.77953, color #000000
#
# Text: 'gefordert. Um diese zusätzliche Unterstützungsarbeit '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.8018, color #000000
#
# Text: 'für  Betroffene leisten zu können, ohne '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #000000
#
# Text: 'uns dabei selbst auszubeuten, haben '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #000000
#
# Text: 'wir uns bei der Konferenz ausgiebig '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.81963, color #000000
#
# Text: 'dem Thema «Fundraising» gewidmet. '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #000000
#
# Text: 'nicht nur die entwicklung der Print-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #000000
#
# Text: 'medien, auch Corona hat uns allen '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.84299, color #000000
#
# Text: 'einbußen bei den  verkaufszahlen '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.84299, color #000000
#
# Text: ' beschert. Wir wollen aber weiterhin '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.84299, color #000000
#
# Text: ' Unterstützung in sozialrechtlichen Fra-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.72211, color #000000
#
# Text: 'gen, Begleitung bei medizinischen notfällen, Zur-verfü-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #000000
#
# Text: 'gung-Stellen von Speis & Trank, Rechtsberatung und Teil-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.70605, color #000000
#
# Text: 'nahme an Kulturprojekten anbieten. '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #000000
#
# Text: 'Wie können wir all das über den Zeitungsverkauf '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.84299, color #000000
#
# Text: 'hinaus finanzieren? erste ansätze gibt es bereits: in '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.84299, color #000000
#
# Text: 'Deutschland und der Schweiz vertrauen Straßenzeitun-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #000000
#
# Text: 'gen auf ihren «Freundeskreis», bei uns in Wien sind wir '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #000000
#
# Text: 'ganz vernarrt in unsere liebhaber:innen. Diese  modelle '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #000000
#
# Text: ' beinhalten nicht nur finanzielle Unterstützung, sondern '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #000000
#
# Text: 'auch ein Zusammenkommen von Spender:innen und '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.78499, color #000000
#
# Text: 'verkäufer:innen, bereichernder austausch inklusive. Das '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.73944, color #000000
#
# Text: 'Fazit des Straßenzeitungs-netzwerks: Diese Unterstüt-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.77446, color #000000
#
# Text: 'zung wollen wir pflegen und ausbauen. Denn gemein-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #000000
#
# Text: 'sam mit euch schaffen wir solidarischen mehrwert! '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #000000
#
# Text: 'cp'
# Font: 'MyriadPro-It' (italic, serifed, proportional), size 8.75589, color #000000
#
# Text: 'Beginn:'
# Font: 'MyriadPro-Bold' (serifed, proportional, bold), size 8.75589, color #ffffff
#
# Text: ' ab sofort'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'Umfang:'
# Font: 'MyriadPro-Bold' (serifed, proportional, bold), size 8.75589, color #ffffff
#
# Text: ' 15 Stunden zu Beginn '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: '(spätere Stundenanzahl auf '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'verhandlungsbasis)'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'Geld: '
# Font: 'MyriadPro-Bold' (serifed, proportional, bold), size 8.75589, color #ffffff
#
# Text: '998 euro brutto/monat'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'Wir suchen eine:n Fundraiser:in mit:'
# Font: 'MyriadPro-Bold' (serifed, proportional, bold), size 8.75589, color #ffffff
#
# Text: '•�'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'erfahrung und Freude bei ak-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'quise und im  Umgang mit gro-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'ßen und kleinen Spender:innen'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: '•�'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'eDv- und Datenbankkenntnissen'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: '•�'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'lust auf das erstellen von Kon-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'zepten & Texten zur  erweiterung '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'unserer Spender:innen-liste '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: '•�'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'interesse an einer sinnstiften-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'den Tätigkeit mit hoher eigen-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'verantwortung und flexibler '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'arbeitszeit einteilung'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'Was erwartet dich bei uns?'
# Font: 'MyriadPro-Bold' (serifed, proportional, bold), size 8.75589, color #ffffff
#
# Text: 'Wir sind ein zwölfköpfiges Team, das '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'alle zwei Wochen den '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'Augustin'
# Font: 'MyriadPro-It' (italic, serifed, proportional), size 8.75589, color #ffffff
#
# Text: ' heraus-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'gibt, augustin-verkäufer:innen unter-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'stützt und darüber hinaus viele  Projekte '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'betreut. Wir arbeiten ohne Chef:in. '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: ' Unsere Gehälter sind alle gleich.'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'Dein Aufgabengebiet umfasst  '
# Font: 'MyriadPro-Bold' (serifed, proportional, bold), size 8.75589, color #ffffff
#
# Text: 'folgende Bereiche: '
# Font: 'MyriadPro-Bold' (serifed, proportional, bold), size 8.75589, color #ffffff
#
# Text: '•�'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'Betreuung bestehender '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'Spender:innen'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: '•�'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'Strategieplanung und -umset-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'zung zur Gewinnung neuer  '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'Spender:innen'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: '•�'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'Zusammenarbeit mit dem '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: ' Gesamtteam und der Öffentlich-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'keitsarbeit im Besonderen'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'Bei Interesse schick uns bitte bis 30. '
# Font: 'MyriadPro-Bold' (serifed, proportional, bold), size 8.75589, color #ffffff
#
# Text: 'Mai ein paar Infos über dich selbst:'
# Font: 'MyriadPro-Bold' (serifed, proportional, bold), size 8.75589, color #ffffff
#
# Text: '•�'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'in welchen Kontexten arbeitest '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'du?'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: '•�'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'aus welchen Projekten, vereinen, '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'nGos trägst du deine erfahrun-'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'gen zusammen?'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'Post an uns: '
# Font: 'MyriadPro-Bold' (serifed, proportional, bold), size 8.75589, color #ffffff
#
# Text: 'verein@augustin.or.at'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'oder verein Sand & Zeit,  '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'Reinprechtsdorfer Str. 31, 1050 Wien'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.75589, color #ffffff
#
# Text: 'Wir freuen uns auf deine Post!'
# Font: 'MyriadPro-Bold' (serifed, proportional, bold), size 8.75589, color #ffffff
#
# Text: 'Das Augustin-Team'
# Font: 'MyriadPro-Bold' (serifed, proportional, bold), size 8.75589, color #ffffff
#
# Text: 'gesucht!'
# Font: 'AmasisMTStd-Bold' (serifed, proportional, bold), size 24, color #ffffff
#
# Text: 'Fundraiser:in'
# Font: 'AmasisMTStd-Bold' (serifed, proportional, bold), size 27, color #ffffff
#
# Text: 'für den'
# Font: 'AmasisMTStd-Bold' (serifed, proportional, bold), size 16, color #ffffff
#
# Text: 'Gemeinsam '
# Font: 'AmasisMTStd-Italic' (italic, serifed, proportional), size 15, color #000000
#
# Text: 'schaffen wir '
# Font: 'AmasisMTStd-Italic' (italic, serifed, proportional), size 15, color #000000
#
# Text: 'solidarischen '
# Font: 'AmasisMTStd-Italic' (italic, serifed, proportional), size 15, color #000000
#
# Text: 'Mehrwert!'
# Font: 'AmasisMTStd-Italic' (italic, serifed, proportional), size 15, color #000000

# %% [markdown]
# ### 3. Option to get text from rectangle using get_textbox(rect)

# %%
rect = fitz.Rect(0, 400, 300, 800)
print(new_page_left.get_textbox(rect))
# Out:
# wos is los …
# … beim Augustin
# D
# as deutschsprachige Straßenzeitungstreffen ende
# april in Hamburg stand im Zeichen des Zusam-
# menhalts. 21 Straßenzeitungen aus Österreich,
# Deutschland und der Schweiz sind der einladung der
# Kolleg:innen von Hinz&Kunzt gefolgt, haben sich ausge-
# tauscht und vor allem gegenseitig bestärkt. Denn  Stärke
# brauchen wir jetzt, um unsere arbeit weiterzuführen.
# Die Teuerungen bringen mehr armut – wir sind mehr
# gefordert. Um diese zusätzliche Unterstützungsarbeit
# für  Betroffene leisten zu können, ohne
# uns dabei selbst auszubeuten, haben
# wir uns bei der Konferenz ausgiebig
# dem Thema «Fundraising» gewidmet.
# nicht nur die entwicklung der Print-
# medien, auch Corona hat uns allen
# einbußen bei den  verkaufszahlen
#  beschert. Wir wollen aber weiterhin
#  Unterstützung in sozialrechtlichen Fra-
# gen, Begleitung bei medizinischen notfällen, Zur-verfü-
# gung-Stellen von Speis & Trank, Rechtsberatung und Teil-
# nahme an Kulturprojekten anbieten.
# Wie können wir all das über den Zeitungsverkauf
# hinaus finanzieren? erste ansätze gibt es bereits: in
# Deutschland und der Schweiz vertrauen Straßenzeitun-
# gen auf ihren «Freundeskreis», bei uns in Wien sind wir
# ganz vernarrt in unsere liebhaber:innen. Diese  modelle
#  beinhalten nicht nur finanzielle Unterstützung, sondern
# auch ein Zusammenkommen von Spender:innen und
# verkäufer:innen, bereichernder austausch inklusive. Das
# Fazit des Straßenzeitungs-netzwerks: Diese Unterstüt-
# zung wollen wir pflegen und ausbauen. Denn gemein-
# sam mit euch schaffen wir solidarischen mehrwert!
# cp
# Gemeinsam
# schaffen wir
# solidarischen
# Mehrwert!

# %% [markdown]
# ## Load page 2 and crop to right page (page 5)

# %%
src = fitz.open("../PyMuPDF_playground/574_augustin_fertig_kontrolle.pdf")
new_doc = fitz.open()  # empty output PDF

page = src.load_page(2)
r = page.rect
d = fitz.Rect(
    # CropBox displacement if being set
    page.cropbox_position,
    page.cropbox_position,
)  # starting at (0, 0)

r1 = r
r1.x1 = r1.x1 / 2  # left side of double page
r2 = r1 + (r1.width, 0, r1.width, 0)  # right side of double page
# r2 = r + (r.width / 2, 0, 0, 0)  # right side of double page

r2 += d  # add the CropBox displacement
new_page_right = new_doc.new_page(-1, width=r2.width, height=r2.height)
new_page_right.show_pdf_page(
    new_page_right.rect,
    src,
    page.number,
    clip=r2,
)
# Out:
# 80

# %% [markdown]
# ### 1. Option to use get_text()

# %%
text = new_page_right.get_text()
print(text)
# Out:
# 574
# 5
# das wahre leben
# F
# ür eine gute Kinder- und Jugendhilfe sind gleiche Standards
# vom Neusiedler- bis zum Bodensee Voraussetzung.  Gerade
# Jugendliche mit schwieriger Lebensgeschichte brauchen
#  Begleitung und Betreuung über das 18. Lebensjahr hinaus. In
# Österreich macht es einen Unterschied, wo ein Kind lebt. Die Hilfen
# unterscheiden sich von Bundesland zu Bundesland.
# Jugendliche, die niemanden haben, der:die für sie sorgt, müssen
# dieselben Chancen erhalten wie jene Kinder, die in Familien auf-
# wachsen dürfen. Deshalb wäre es vernünftig, dass
# junge Menschen auch über den 18. Geburtstag hi-
# naus einen Rechtsanspruch auf  Kinder- und Ju-
# gendhilfe bekommen. Auch in  einer Familie endet
# die Sorge und Unterstützung nicht einfach mit dem
# 18. Geburtstag. Und hier geht es um Jugendliche
# mit schwierigsten Lebensgeschichten. Diese Be-
# gleitung wirkt stark präventiv und beugt Abstür-
# zen vor, wie wir aus anderen europäischen Län-
# dern wissen. Im Schnitt ziehen junge Menschen hierzulande mit 24
# Jahren von zu Hause aus – und auch dann werden viele noch weiter
# unterstützt. Anders ist es jedoch ausgerechnet bei den Jugendlichen,
# die außerhalb der Familie, also in Wohngemeinschaften oder Pflege-
# familien aufwachsen.
# Seitdem die Zuständigkeit allein bei den Bundesländern liegt, kann
# sich die Kinder- und Jugendhilfe bundesweit kaum noch weiterentwi-
# ckeln. Dieser föderale Dschungel wurde von der letzten türkis- blauen
# Regierung mit einer speziellen Vereinbarung geschaffen. Diese friert
# den Status des Bundes-Kinder- und Jugendhilfegesetzes ein. Fort-
# schritte sind nur möglich, wenn alle neun Bundesländer gemeinsam
# diesen Verbesserungen zustimmen. Für einen solchen Prozess gibt
# es aber keinerlei festgelegte Strukturen. Es regiert der kleinste und
# schlechteste gemeinsame Nenner. Eine bundesweite Weiterentwick-
# lung ist praktisch unmöglich.
# Ein deutliches Beispiel für die «Versteinerung» sind die soge-
# nannten «Hilfen für junge Erwachsene», auch als «Care Leaver»
#  bezeichnet. Vor kurzem wurde in Oberösterreich eine generelle Un-
# terstützung junger Erwachsener über das 21. Lebensjahr hinaus mit
# der Begründung abgelehnt, dass die getroffene Länder-Vereinbarung
# dies nicht zulasse. In Salzburg wurde die Neuauf-
# nahme von Jugendlichen in die Maßnahmen der
# Jugendhilfe vom 18. bis zum 21. Lebensjahr mit
# demselben Argument abgelehnt. Eigentlich war die
# Länder-Vereinbarung zur Bewahrung der Mindest-
# standards in der Jugendhilfe geschlossen worden.
# Nun «wurde sie zum Bumerang, friert den Status
# Quo ein und verhindert eine positive Weiterent-
# wicklung der Jugendhilfe in Österreich», beklagt
# der seit  Jahren  engagierte Kinderrechtler Hubert Löffler.
# Unterstützung soll aber sinnvollerweise nicht nur im äußersten
# Krisenfall einsetzen, sondern vor allem vorher greifen und besonde-
# ren Belastungen vorbeugen. Es geht hier nicht nur um Kosten, son-
# dern um Investitionen. Man kann aus Menschenliebe oder Gerech-
# tigkeitsvorstellungen für eine gescheite Jugendhilfe sein. Man kann
# aber auch rein ökonomische Argumente anführen. Mangelnde Hil-
# fe erzeugt Kosten anderswo, wenn die Jugendlichen keinen Job fin-
# den, in schwierige Verhältnisse oder Kriminalität abdriften oder ein
# höheres Krankheitsrisiko entsteht. Auf gute Hilfe müssen benachtei-
# ligte Kinder und Jugendliche ein Recht haben. Und das ist nicht ins
# Belieben der Bundesländer zu stellen.
# ■
# Mangelnde Hilfe
# erzeugt Kosten
# anderswo
# eingSCHENKt
# Versteinerung der Kinder-
# und Jugendhilfe
#  von
# maRTin SCHenK

# %%
words = new_page_right.get_text("words") # get plain text (is in UTF-8)
print(words)
# Out:
# [(26.389549255371094, 38.286529541015625, 42.34954833984375, 56.74810791015625, '574', 0, 0, 0), (587.6253662109375, 31.114707946777344, 600.9453735351562, 60.8507080078125, '5', 1, 0, 0), (472.0771484375, 42.076210021972656, 492.5679626464844, 58.4757080078125, 'das', 1, 1, 0), (495.58056640625, 42.076210021972656, 532.3419799804688, 58.4757080078125, 'wahre', 1, 1, 1), (535.3546142578125, 42.076210021972656, 568.9186401367188, 58.4757080078125, 'leben', 1, 1, 2), (33.75738525390625, 169.43218994140625, 66.89643859863281, 254.17079162597656, 'F', 2, 0, 0), (67.41845703125, 191.945556640625, 76.35286712646484, 205.0365447998047, 'ür', 3, 0, 0), (77.80322265625, 191.945556640625, 94.86323547363281, 205.0365447998047, 'eine', 3, 0, 1), (96.3135986328125, 191.945556640625, 113.58558654785156, 205.0365447998047, 'gute', 3, 0, 2), (115.03594970703125, 191.945556640625, 146.61790466308594, 205.0365447998047, 'Kinder-', 3, 0, 3), (148.0682373046875, 191.945556640625, 163.53846740722656, 205.0365447998047, 'und', 3, 0, 4), (164.98883056640625, 191.945556640625, 212.52626037597656, 205.0365447998047, 'Jugendhilfe', 3, 0, 5), (213.97662353515625, 191.945556640625, 231.1853790283203, 205.0365447998047, 'sind', 3, 0, 6), (232.6357421875, 191.945556640625, 261.1125183105469, 205.0365447998047, 'gleiche', 3, 0, 7), (262.5628662109375, 191.945556640625, 303.4399108886719, 205.0365447998047, 'Standards', 3, 0, 8), (67.41845703125, 203.24560546875, 84.59545135498047, 216.3365936279297, 'vom', 3, 1, 0), (86.8531494140625, 203.24560546875, 134.3712615966797, 216.3365936279297, 'Neusiedler-', 3, 1, 1), (136.63360595703125, 203.24560546875, 148.44798278808594, 216.3365936279297, 'bis', 3, 1, 2), (150.70562744140625, 203.24560546875, 167.9942626953125, 216.3365936279297, 'zum', 3, 1, 3), (170.256591796875, 203.24560546875, 208.7627410888672, 216.3365936279297, 'Bodensee', 3, 1, 4), (211.0250244140625, 203.24560546875, 272.2278747558594, 216.3365936279297, 'Voraussetzung.', 3, 1, 5), (274.472900390625, 203.24560546875, 303.3059387207031, 216.3365936279297, 'Gerade', 3, 1, 6), (67.41845703125, 214.54559326171875, 117.74178314208984, 227.63658142089844, 'Jugendliche', 3, 2, 0), (120.2969970703125, 214.54559326171875, 134.59666442871094, 227.63658142089844, 'mit', 3, 2, 1), (137.15185546875, 214.54559326171875, 185.74142456054688, 227.63658142089844, 'schwieriger', 3, 2, 2), (188.296630859375, 214.54559326171875, 262.0370178222656, 227.63658142089844, 'Lebensgeschichte', 3, 2, 3), (264.59222412109375, 214.54559326171875, 303.3915100097656, 227.63658142089844, 'brauchen', 3, 2, 4), (67.41845703125, 225.8455810546875, 110.00690460205078, 238.9365692138672, 'Begleitung', 3, 3, 0), (111.42584228515625, 225.8455810546875, 126.78987884521484, 238.9365692138672, 'und', 3, 3, 1), (128.2078857421875, 225.8455810546875, 169.796142578125, 238.9365692138672, 'Betreuung', 3, 3, 2), (171.215087890625, 225.8455810546875, 189.42637634277344, 238.9365692138672, 'über', 3, 3, 3), (190.8453369140625, 225.8455810546875, 204.33273315429688, 238.9365692138672, 'das', 3, 3, 4), (205.750732421875, 225.8455810546875, 216.7671661376953, 238.9365692138672, '18.', 3, 3, 5), (218.18609619140625, 225.8455810546875, 262.9533996582031, 238.9365692138672, 'Lebensjahr', 3, 3, 6), (264.3714599609375, 225.8455810546875, 293.16461181640625, 238.9365692138672, 'hinaus.', 3, 3, 7), (294.5826416015625, 225.8455810546875, 303.4201965332031, 238.9365692138672, 'In', 3, 3, 8), (35.4332275390625, 237.14556884765625, 78.43594360351562, 250.23655700683594, 'Österreich', 3, 4, 0), (80.0279541015625, 237.14556884765625, 105.30458068847656, 250.23655700683594, 'macht', 3, 4, 1), (106.8966064453125, 237.14556884765625, 115.40592193603516, 250.23655700683594, 'es', 3, 4, 2), (116.9979248046875, 237.14556884765625, 139.4163818359375, 250.23655700683594, 'einen', 3, 4, 3), (141.0084228515625, 237.14556884765625, 192.64987182617188, 250.23655700683594, 'Unterschied,', 3, 4, 4), (194.23724365234375, 237.14 ...

# %% [markdown]
# ### 2. Option to print out each line with meta information

# %%
def flags_decomposer(flags):
    """Make font flags human readable."""
    l = []
    if flags & 2 ** 0:
        l.append("superscript")
    if flags & 2 ** 1:
        l.append("italic")
    if flags & 2 ** 2:
        l.append("serifed")
    else:
        l.append("sans")
    if flags & 2 ** 3:
        l.append("monospaced")
    else:
        l.append("proportional")
    if flags & 2 ** 4:
        l.append("bold")
    return ", ".join(l)


# read page text as a dictionary, suppressing extra spaces in CJK fonts
blocks = new_page_right.get_text("dict", flags=11)["blocks"]
for b in blocks:  # iterate through the text blocks
    for l in b["lines"]:  # iterate through the text lines
        for s in l["spans"]:  # iterate through the text spans
            print("")
            font_properties = "Font: '%s' (%s), size %g, color #%06x" % (
                s["font"],  # font name
                flags_decomposer(s["flags"]),  # readable font flags
                s["size"],  # font size
                s["color"],  # font color
            )
            print("Text: '%s'" % s["text"])  # simple print of text
            print(font_properties)
# Out:
# Text: '574'
# Font: 'MyriadPro-BlackCond' (serifed, proportional, bold), size 13.9298, color #f3664e
#
# Text: '5'
# Font: 'MyriadPro-Bold' (serifed, proportional, bold), size 24, color #000000
#
# Text: 'das wahre leben '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 14.3543, color #f3664e
#
# Text: 'F'
# Font: 'Sentinel-Book' (serifed, proportional), size 56.6946, color #f3664e
#
# Text: 'ür eine gute Kinder- und Jugendhilfe sind gleiche Standards '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.39795, color #000000
#
# Text: 'vom Neusiedler- bis zum Bodensee Voraussetzung.  Gerade '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'Jugendliche mit schwieriger Lebensgeschichte brauchen '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.48183, color #000000
#
# Text: ' Begleitung und Betreuung über das 18. Lebensjahr hinaus. In '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.37128, color #000000
#
# Text: 'Österreich macht es einen Unterschied, wo ein Kind lebt. Die Hilfen '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'unterscheiden sich von Bundesland zu Bundesland.'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'Jugendliche, die niemanden haben, der:die für sie sorgt, müssen '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'dieselben Chancen erhalten wie jene Kinder, die in Familien auf-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.45454, color #000000
#
# Text: 'wachsen dürfen. Deshalb wäre es vernünftig, dass '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'junge Menschen auch über den 18. Geburtstag hi-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'naus einen Rechtsanspruch auf  Kinder- und Ju-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.43478, color #000000
#
# Text: 'gendhilfe bekommen. Auch in  einer Familie endet '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'die Sorge und Unterstützung nicht einfach mit dem '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.3284, color #000000
#
# Text: '18. Geburtstag. Und hier geht es um Jugendliche '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.42001, color #000000
#
# Text: 'mit schwierigsten Lebensgeschichten. Diese Be-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.43221, color #000000
#
# Text: 'gleitung wirkt stark präventiv und beugt Abstür-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.4128, color #000000
#
# Text: 'zen vor, wie wir aus anderen europäischen Län-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.45529, color #000000
#
# Text: 'dern wissen. Im Schnitt ziehen junge Menschen hierzulande mit 24 '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'Jahren von zu Hause aus – und auch dann werden viele noch weiter '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'unterstützt. Anders ist es jedoch ausgerechnet bei den Jugendlichen, '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.37533, color #000000
#
# Text: 'die außerhalb der Familie, also in Wohngemeinschaften oder Pflege-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.39735, color #000000
#
# Text: 'familien aufwachsen. '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'Seitdem die Zuständigkeit allein bei den Bundesländern liegt, kann '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.31678, color #000000
#
# Text: 'sich die Kinder- und Jugendhilfe bundesweit kaum noch weiterentwi-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.31, color #000000
#
# Text: 'ckeln. Dieser föderale Dschungel wurde von der letzten türkis- blauen '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.34722, color #000000
#
# Text: 'Regierung mit einer speziellen Vereinbarung geschaffen. Diese friert '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.37903, color #000000
#
# Text: 'den Status des Bundes-Kinder- und Jugendhilfegesetzes ein. Fort-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'schritte sind nur möglich, wenn alle neun Bundesländer gemeinsam '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'diesen Verbesserungen zustimmen. Für einen solchen Prozess gibt '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'es aber keinerlei festgelegte Strukturen. Es regiert der kleinste und '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'schlechteste gemeinsame Nenner. Eine bundesweite Weiterentwick-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.34834, color #000000
#
# Text: 'lung ist praktisch unmöglich.'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'Ein deutliches Beispiel für die «Versteinerung» sind die soge-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.48429, color #000000
#
# Text: 'nannten «Hilfen für junge Erwachsene», auch als «Care Leaver» '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.49155, color #000000
#
# Text: ' bezeichnet. Vor kurzem wurde in Oberösterreich eine generelle Un-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'terstützung junger Erwachsener über das 21. Lebensjahr hinaus mit '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'der Begründung abgelehnt, dass die getroffene Länder-Vereinbarung '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.37994, color #000000
#
# Text: 'dies nicht zulasse. In Salzburg wurde die Neuauf-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'nahme von Jugendlichen in die Maßnahmen der '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.42515, color #000000
#
# Text: 'Jugendhilfe vom 18. bis zum 21. Lebensjahr mit '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.46925, color #000000
#
# Text: 'demselben Argument abgelehnt. Eigentlich war die '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.32682, color #000000
#
# Text: 'Länder-Vereinbarung zur Bewahrung der Mindest-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.31923, color #000000
#
# Text: 'standards in der Jugendhilfe geschlossen worden. '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'Nun «wurde sie zum Bumerang, friert den Status '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'Quo ein und verhindert eine positive Weiterent-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.43085, color #000000
#
# Text: 'wicklung der Jugendhilfe in Österreich», beklagt '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40755, color #000000
#
# Text: 'der seit  Jahren  engagierte Kinderrechtler Hubert Löffler. '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'Unterstützung soll aber sinnvollerweise nicht nur im äußersten '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'Krisenfall einsetzen, sondern vor allem vorher greifen und besonde-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'ren Belastungen vorbeugen. Es geht hier nicht nur um Kosten, son-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'dern um Investitionen. Man kann aus Menschenliebe oder Gerech-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'tigkeitsvorstellungen für eine gescheite Jugendhilfe sein. Man kann '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'aber auch rein ökonomische Argumente anführen. Mangelnde Hil-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'fe erzeugt Kosten anderswo, wenn die Jugendlichen keinen Job fin-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'den, in schwierige Verhältnisse oder Kriminalität abdriften oder ein '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'höheres Krankheitsrisiko entsteht. Auf gute Hilfe müssen benachtei-'
# Font: 'Sentinel-Book' (serifed, proportional), size 9.35784, color #000000
#
# Text: 'ligte Kinder und Jugendliche ein Recht haben. Und das ist nicht ins '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: 'Belieben der Bundesländer zu stellen. '
# Font: 'Sentinel-Book' (serifed, proportional), size 9.40452, color #000000
#
# Text: '■'
# Font: 'ZapfDingbatsITC' (sans, proportional), size 9.40452, color #f3664e
#
# Text: 'Mangelnde Hilfe  '
# Font: 'AmasisMTStd-Italic' (italic, serifed, proportional), size 18, color #000000
#
# Text: 'erzeugt Kosten  '
# Font: 'AmasisMTStd-Italic' (italic, serifed, proportional), size 18, color #000000
#
# Text: 'anderswo'
# Font: 'AmasisMTStd-Italic' (italic, serifed, proportional), size 18, color #000000
#
# Text: 'eingSCHENKt'
# Font: 'MyriadPro-SemiCn' (serifed, proportional), size 14.3543, color #000000
#
# Text: 'Versteinerung der Kinder- '
# Font: 'AmasisMTStd-Bold' (serifed, proportional, bold), size 32, color #000000
#
# Text: 'und Jugendhilfe'
# Font: 'AmasisMTStd-Bold' (serifed, proportional, bold), size 32, color #000000
#
# Text: ' von '
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.90954, color #000000
#
# Text: 'maRTin SCHenK'
# Font: 'MyriadPro-Regular' (serifed, proportional), size 8.90954, color #000000

# %% [markdown]
# ### 3. Option to get text from rectangle using get_textbox(rect)

# %%
rect_right = fitz.Rect(0, 100, 600, 800)
print(new_page_right.get_textbox(rect_right))
# Out:
# F
# ür eine gute Kinder- und Jugendhilfe sind gleiche Standards
# vom Neusiedler- bis zum Bodensee Voraussetzung.  Gerade
# Jugendliche mit schwieriger Lebensgeschichte brauchen
#  Begleitung und Betreuung über das 18. Lebensjahr hinaus. In
# Österreich macht es einen Unterschied, wo ein Kind lebt. Die Hilfen
# unterscheiden sich von Bundesland zu Bundesland.
# Jugendliche, die niemanden haben, der:die für sie sorgt, müssen
# dieselben Chancen erhalten wie jene Kinder, die in Familien auf-
# wachsen dürfen. Deshalb wäre es vernünftig, dass
# junge Menschen auch über den 18. Geburtstag hi-
# naus einen Rechtsanspruch auf  Kinder- und Ju-
# gendhilfe bekommen. Auch in  einer Familie endet
# die Sorge und Unterstützung nicht einfach mit dem
# 18. Geburtstag. Und hier geht es um Jugendliche
# mit schwierigsten Lebensgeschichten. Diese Be-
# gleitung wirkt stark präventiv und beugt Abstür-
# zen vor, wie wir aus anderen europäischen Län-
# dern wissen. Im Schnitt ziehen junge Menschen hierzulande mit 24
# Jahren von zu Hause aus – und auch dann werden viele noch weiter
# unterstützt. Anders ist es jedoch ausgerechnet bei den Jugendlichen,
# die außerhalb der Familie, also in Wohngemeinschaften oder Pflege-
# familien aufwachsen.
# Seitdem die Zuständigkeit allein bei den Bundesländern liegt, kann
# sich die Kinder- und Jugendhilfe bundesweit kaum noch weiterentwi-
# ckeln. Dieser föderale Dschungel wurde von der letzten türkis- blauen
# Regierung mit einer speziellen Vereinbarung geschaffen. Diese friert
# den Status des Bundes-Kinder- und Jugendhilfegesetzes ein. Fort-
# schritte sind nur möglich, wenn alle neun Bundesländer gemeinsam
# diesen Verbesserungen zustimmen. Für einen solchen Prozess gibt
# es aber keinerlei festgelegte Strukturen. Es regiert der kleinste und
# schlechteste gemeinsame Nenner. Eine bundesweite Weiterentwick-
# lung ist praktisch unmöglich.
# Ein deutliches Beispiel für die «Versteinerung» sind die soge-
# nannten «Hilfen für junge Erwachsene», auch als «Care Leaver»
#  bezeichnet. Vor kurzem wurde in Oberösterreich eine generelle Un-
# terstützung junger Erwachsener über das 21. Lebensjahr hinaus mit
# der Begründung abgelehnt, dass die getroffene Länder-Vereinbarung
# dies nicht zulasse. In Salzburg wurde die Neuauf-
# nahme von Jugendlichen in die Maßnahmen der
# Jugendhilfe vom 18. bis zum 21. Lebensjahr mit
# demselben Argument abgelehnt. Eigentlich war die
# Länder-Vereinbarung zur Bewahrung der Mindest-
# standards in der Jugendhilfe geschlossen worden.
# Nun «wurde sie zum Bumerang, friert den Status
# Quo ein und verhindert eine positive Weiterent-
# wicklung der Jugendhilfe in Österreich», beklagt
# der seit  Jahren  engagierte Kinderrechtler Hubert Löffler.
# Unterstützung soll aber sinnvollerweise nicht nur im äußersten
# Krisenfall einsetzen, sondern vor allem vorher greifen und besonde-
# ren Belastungen vorbeugen. Es geht hier nicht nur um Kosten, son-
# dern um Investitionen. Man kann aus Menschenliebe oder Gerech-
# tigkeitsvorstellungen für eine gescheite Jugendhilfe sein. Man kann
# aber auch rein ökonomische Argumente anführen. Mangelnde Hil-
# fe erzeugt Kosten anderswo, wenn die Jugendlichen keinen Job fin-
# den, in schwierige Verhältnisse oder Kriminalität abdriften oder ein
# höheres Krankheitsrisiko entsteht. Auf gute Hilfe müssen benachtei-
# ligte Kinder und Jugendliche ein Recht haben. Und das ist nicht ins
# Belieben der Bundesländer zu stellen.
# ■
# Mangelnde Hilfe
# erzeugt Kosten
# anderswo
# eingSCHENKt
# Versteinerung der Kinder-
# und Jugendhilfe
#  von
# maRTin SCHenK
